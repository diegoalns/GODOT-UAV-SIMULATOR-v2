# %%
# Test Python kernel connection
import pandas as pd
import numpy as np
print('Kernel connected successfully!')
print(f'Pandas version: {pd.__version__}')
print(f'NumPy version: {np.__version__}')
